# %% [markdown]
# # Problème inverse : Assignation de données
#
# On considère l'équation de la chaleur stationnaire avec terme source dans un domaine $\Omega = [0 , L] \times [0 , H]$ :
#
# $$
# \left\{
#     \begin{array}{ll}
#         \Delta u = f & \text{dans } \Omega \\
#         u = 0 & \text{sur } \partial \Omega
#     \end{array}
# \right.
# $$
#
# et alors
# $(u, f) \in V = \left\{ u \in H^1_0(\Omega), f \in L^2(\Omega) \; \big\lvert \; \Delta u = f \right\}.$
#
# On considère $N$ points $(x_i, y_i) \in \Omega$ où la température $T_i$ est fixée (mesurée).
#
# On cherche à minimiser la quantité:
#
# $$
# I = \sum_{i=1}^N \left( u(x_i, y_i) - T_i \right)^2
# $$
#
# sur $(u, f) \in V$ pour reconstruire la solution $u$ à partir des $T_i$.

# %% [markdown]
# # Equation de la chaleur par différences finies 2D
#
# Dans un premier temps, il faut simuler l'équation de la chaleur stationnaire 2D par différences finies sur une grille cartésienne afin de se pouvoir calculer $T_i$.
#
# On se donne le maillage suivant:
#
# ![Maillage en espace ($(i,j) \in [0,n_x + 1] \times [0,n_y + 1]$ et $[x_0,x_{n_x + 1}] \times [y_0,y_{n_y + 1}] = [0;L_x] \times [0;L_y]$)](mesh.png)
#
# Maillage en espace ($(i,j) \in [0,n_x + 1] \times [0,n_y + 1]$ et $[x_0,x_{n_x + 1}] \times [y_0,y_{n_y + 1}] = [0;L_x] \times [0;L_y]$)
#
# On approche l'équation $\Delta u = f$ par le schéma suivant:
#
# $$
# \frac{2 u_{i,j} - u_{i+1,j} - u_{i-1,j}}{\Delta x^2} + \frac{2 u_{i,j} - u_{i,j+1} - u_{i,j-1}}{\Delta y^2} = f_{i,j}
# $$
#
# Afin de pouvoir écrire ce schéma sous forme matricielle on va changer la numérotation des indices en posant
#
# $k = i - 1 + n_x (j-1)$, soit $u_{k} = u_{i,j}$.
#
# On retombe sur $i$ et $j$ avec $i = k \% n_x  + 1$ et $j = (k - i + 1) // n_x + 1$ (le reste et la partie entière de $k$ par $n_x$).On obtient donc le nouveau schéma:
#
# $$
#     \frac{2 u_{k} - u_{k+1} - u_{k-1}}{\Delta x^2} + \frac{2 u_{k} - u_{k+n_x} - u_{k-n_x}}{\Delta y^2} = f_{k}
# $$
#
# On peux donc écrire le schéma sous forme matricielle (sans considérer les bords):
#
# $$
#     A U = b
# $$
#
# où $U = (u_{k})_{k \in I}$ ($I = [0, n_x n_y - 1]$), $b = (f_{k})_{k \in I}$ et la matrice $A = a_{kl}$ la matrice du laplacien 2D:
#
# $$
# a_{kl} =
# \begin{cases}
# \frac{2}{\Delta x^2} + \frac{2}{\Delta y^2}, & \text{si } k = l \\
# \frac{-1}{\Delta x^2}, & \text{si } i = j - 1 \text{ ou } k = l + 1\\
# \frac{-1}{\Delta y^2}, & \text{si } i = j - n_x \text{ ou } k = l + n_x\\
# 0, & \text{sinon}
# \end{cases}
# $$

# %% [markdown]
# ## Solveur utilisé : Gradient Conjugué
#
# ### Algo:
#
# $k = 0$,\
# $r_k = b - A x_0$,\
# $p=r_k$
#
# **Tant que** ($ \|r_k\| > \epsilon$) et ($k \leq k_{max}$)  **faire**
#
# $z = Ap$,\
# $\alpha = \frac{<r_k,r_k>}{<z,p>}$,\
# $x=x-\alpha p$,\
# $r_{k+1} = r_k - \alpha z$,\
# $\gamma = \frac{<r_{k+1},r_{k+1}>}{<r_{k}, r_{k}>}$,\
# $p = r_{k+1} + \gamma p$,\
# $k=k+1$,
#
# **Fin Tant Que**
#
# **Retourner** k, x

# %% [markdown]
# # Fonction *heat* pour simuler l'équation de la chaleur stationnaire

# %%
import numpy  as np
import time
import random as rd
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.sparse import diags

def heat(nx, ny, u0, f, L=1, H=1, max_iter=10000, epsilon=1e-7):
    """ Fonction simulant l'équation de la chaleur stationnaire 2D sur un maillage cartésien uniforme par différences finies
    avec des conditions aux limites de type Dirichlet homogène. Arguments :
        - nx : nombre de mailles selon x
        - ny : nombre de mailles selon y
        - u0 : solution initiale (scalaire)
        - f : terme source (fonction prenant 2 scalaires (x, y) en entrée pour retourner un scalaire f(x, y))
        - L : longueur du domaine (= 1 par défaut)
        - H : hauteur du domaine (= 1 par défaut)
        - max_iter : nombre maximal d'itérations pour le gradient conjugué (= 10000 par défaut)
        - epsilon : seuil d'erreur minimal pour le gradient conjugué (= 1e-7 par défaut) """

       # Construction du maillage : liste P des points P(i,j) = (x(i), y(j)) 
    # du maillage indexés par k = i - 1 + nx * (j - 1)
    N = nx * ny
    dx = L / (nx+1)
    dy = H / (ny+1)
    P = np.array([[[i * dx, j * dy] for i in range(1, nx + 1)] for j in range(1, ny + 1)]) 
    P = P.reshape(N, 2)

    # Construction du système linéaire Au = b
    
    N = nx * ny
    alpha = 2 * (1 / dx**2 + 1 / dy**2) * np.ones(N) # Diagonale de A
    beta = - np.ones(N - 1) / dx ** 2 # Diagonales décalées de 1 indice
    beta[nx - 1::nx] = 0 # Brisures de la diagonale
    gamma = - np.ones(N - nx) / dy ** 2 # Diagonale décalée de nx indices
    k = [gamma, beta, alpha, beta, gamma]
    offset = [-nx, -1, 0, 1, nx]
    A = diags(k, offset).toarray() # Matrice A
    b = np.array([f(P[k, 0], P[k, 1]) for k in range(N)]) # Second membre b

    # Résolution du système linéaire
    
    u = u0 * np.ones(N) 
    rk = b - np.dot(A,u)
    p = rk
    k = 0
    kmax = max_iter

    while np.linalg.norm(rk) > epsilon and k < kmax:
        z = np.dot(A, p)
        alpha = np.dot(rk,p) / np.dot(z, p)
        u = u - alpha * p
        rkp1 = rk - alpha * z
        gamma =  np.dot(rkp1,rkp1) / np.dot(rk,rk)
        p = rkp1 + gamma * p
        rk = rkp1
        k += 1
        
    print("Nombre d'itérations du gradient conjugué: ", k)
    print("Résidu du gradient conjugué: ", np.linalg.norm(rk))

    u2D = u.reshape(Nx, Ny)
    u = np.zeros((Nx+2, Ny+2))
    u[1:-1, 1:-1] = u2D

    
    return u, A, b, u2D

# %% [markdown]
# # Test de la fonction *heat*

# %%
# Définition du terme source

def TS(x,y):
    
    return np.cos(x) + np.sin(y)

# Définition des paramètres

Nx = 100
Ny = 100
H = 21
L = 21

# Résolution du problème

T = heat(Nx, Ny, 0, TS, H=H, L=L)[0]

# Affichage du résultat

plt.imshow(T, origin='lower', cmap='jet', extent=[0, L, 0, H])
cbar = plt.colorbar() 
cbar.set_label('T')

plt.xlabel('x')  # Légende de l'axe X
plt.ylabel('y')  # Légende de l'axe Y
plt.title(r'Solution de $\Delta T(x,y) = TS(x,y)$')  # Titre du graphique

plt.show()
# Out:
# Nombre d'itérations du gradient conjugué:  300
# Résidu du gradient conjugué:  9.429228779517865e-08

# %% [markdown]
# # Vérification
#
# On choisit ici la solution pour la solution exacte :
#
# $$
# u_{exact}(x,y) = \frac{1}{LH} x \cdot y \cdot (L - x) \cdot (H - y)
# $$
#
# qui respecte bien les conditions de dirichlet imposées aux bords.
#
# On calcul le terme source associé $f_{exact} = \frac{\partial^2 u_{exact}}{\partial x^2} + \frac{\partial^2 u_{exact}}{\partial y^2}$ :
#
# $$
# u_{exact}(x,y) =\frac{1}{LH}(LHxy - Hx^2y - Lxy^2 + x^2 y^2)
# $$
#
# On en déduit donc :
#
# $$
# f_{exact}(x,y) = \frac{1}{LH} (- 2Hy + 2y^2 - 2Lx + 2x^2)
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Définition des paramètres

Nx = 150
Ny = 150
H = 7
L = 7

# Définition du terme source

def TS(x,y):
    
    return 2 * (x**2 + y**2 - (L*x + H*y)) / (L*H)


# Résolution du problème

T = heat(Nx, Ny, 0, TS, H=H, L=L, epsilon=1e-7)[0]

# Vérification

def u_exact(x,y):
    
    return x*y*(L-x)*(H-y) / (L * H)

# Calcul de la solution exacte
X, Y = np.meshgrid(np.linspace(0, L, Nx+2), np.linspace(0, H, Ny+2))
U_exact = u_exact(X, Y)

# Calcul de la différence
diff = np.abs(T - U_exact)

# Ajustement de la taille de la figure pour une meilleure visibilité des barres de couleur
plt.figure(figsize=(15, 5)) # Figure plus large

# Affichage de la solution numérique
plt.subplot(1, 3, 1)
plt.imshow(T, origin='lower', cmap='jet', extent=[0, L, 0, H])
plt.colorbar(label='T numérique')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r'Solution Numérique')

# Affichage de la solution exacte
plt.subplot(1, 3, 2)
plt.imshow(U_exact, origin='lower', cmap='jet', extent=[0, L, 0, H])
plt.colorbar(label='T exact')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r'Solution Exacte')

# Affichage de la différence
plt.subplot(1, 3, 3)
plt.imshow(diff, origin='lower', cmap='jet', extent=[0, L, 0, H])
plt.colorbar(label='Différence')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r'Différence Absolue')

plt.tight_layout()
plt.show()
# Out:
# Nombre d'itérations du gradient conjugué:  268
# Résidu du gradient conjugué:  9.150305788490672e-08

# %% [markdown]
# # Algorithme descente de Gradient sur le terme source
#
# On considère la promblème discrétisé : $AU = b$
#
# Et on réécrit sous forme vectorielle la fonctionnelle $I(u) = \sum_{i \in E_m} (u(x_i, y_i) - T_i)^2$ où $E_m$ représente l'ensemble des indices $i \in [0, N_x N_y]$ des points $(x_i, y_i)$ où la solution exacte $T$ est mesurée:
#
# $$
#     I(u) = (U-T,U-T)_{\Gamma} = (U-T) \Gamma (U-T)
# $$
#
# où $U = (u(x_i, y_j))_{(i,j) \in [0, N_x] \times [0, N_y]}$,  $T = (T_k)_{k \in [0, N_x N_y]}$ et $\Gamma$ la matrice non inversible suivante:
#
# $$
# \Gamma_{ij} =
# \begin{cases}
# 1, & \text{si } i=j \text{ et } i \in E_m\\
# 0, & \text{sinon}
# \end{cases}
# $$
#
#
# On va donc chercher à minimiser $I$ par rapport à $u$ tout en respectant la containte $AU=b$.
#
#
# Pour simplifer le problème, va remplacer U par b dans la contrainte:
#
# $$
#     I(b) = (A^{-1}b-T,A^{-1}b-T)_{\Gamma}
# $$
#
# On en déduit donc:
#
# $$
#     I'(b) = 2 \Gamma (A^{-1}b-T)
# $$
#
# On peut donc mettre $b$ à jour : $b = b - \beta I'(b)$ avec un pas d'apprentissage $\beta$.
#
# Ensuite on recalcul $U$ (avec le gradient conjugué) pour respecter la contrainte.

# %%
from tqdm.notebook import tqdm

def gradient_conjugue(A, b, u0, max_iter=10000, epsilon=1e-7):
    u = u0 * np.ones(len(b))
    rk = b - np.dot(A, u)
    p = rk
    k = 0

    while np.linalg.norm(rk) > epsilon and k < max_iter:
        Ap = np.dot(A, p)
        alpha = np.dot(rk, p) / np.dot(Ap, p)
        u += alpha * p
        rkp1 = rk - alpha * Ap
        beta = np.dot(rkp1, rkp1) / np.dot(rk, rk)
        p = rkp1 + beta * p
        rk = rkp1
        k += 1

    return u, k, np.linalg.norm(rk)


# Définition des paramètres

Nx = 20
Ny = 20
H = 7
L = 7

# Définition du terme source

def TS(x,y):
    
    return 2 * (x**2 + y**2 - (L*x + H*y)) / (L*H)


# Résolution du problème (solution exacte)
Uex, A, bex, Tex = heat(Nx, Ny, 0, TS, H=H, L=L, epsilon=1e-7)

N = 1000 # Nombre de points de mesures de la température exacte < Nx*Ny
Gamma = np.zeros(Nx*Ny)
# Indices des points non nuls sur la diagonale
indices = np.linspace(0, Nx*Ny - 1, N, dtype=int)
# Placement des 1 sur la diagonale à ces indices
Gamma[indices] = 1

u = np.zeros(Nx*Ny)
b = np.zeros(Nx*Ny)
T = Tex.flatten()
errmax = []
mse = []

nbiter = 100
beta = 0.1
dx = L / (Nx+1)
dy = H / (Ny+1)

# Création de l'instance de la barre de progression
pbar = tqdm(range(nbiter), desc="Processing")

for i in pbar:
    b = b - beta * (2 * Gamma * (u - T))
    u, k, rk =  gradient_conjugue(A, b, u, max_iter=10000, epsilon=1e-7)
    errmax.append(np.abs(u - T).max() / np.abs(T).max())
    mse.append(np.mean((u - T) ** 2) / np.mean(T ** 2))
    beta = errmax[-1]/10
    # Mise à jour de la barre de progression avec la valeur de l'erreur
    pbar.set_postfix(erreur_max_absolue=errmax[-1], mse = mse[-1], itérations_CG=k, erreur_CG=rk)
# Out:
# Nombre d'itérations du gradient conjugué:  33
# Résidu du gradient conjugué:  8.305637458204108e-08
# Processing:   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# ### Affichage des résultats

# %%
errmax = np.array(errmax)
mse = np.array(mse)

u2D = u.reshape(Nx, Ny)
T2D = T.reshape(Nx, Ny)

# Calcul de la différence
diff = np.abs(u2D - T2D)

plt.plot(np.arange(0, mse.shape[0], 1), errmax, label=r'$L_{\infty}$')
plt.plot(np.arange(0, mse.shape[0], 1), mse, label=r'MSE')
plt.ylim(0, 1)
plt.grid()
plt.xlabel('itérations', fontsize=16)
plt.ylabel(r'$\frac{||u_{num} - u_{exacte} ||}{||u_{exacte}||}$', fontsize=18, fontweight='bold')
plt.title("Erreurs relative en fonction des itérations", fontsize=18)
plt.legend(loc='best')
plt.show()


# Ajustement de la taille de la figure pour une meilleure visibilité des barres de couleur
plt.figure(figsize=(15, 5)) # Figure plus large

# Affichage de la solution numérique
plt.subplot(1, 3, 2)
plt.imshow(u2D, origin='lower', cmap='jet', extent=[0, len(u2D[0]), 0, len(u2D)])
plt.colorbar(label='T numérique')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r'Solution Numérique')

# Affichage de la solution du gradient projeté
plt.subplot(1, 3, 1)
plt.imshow(T2D, origin='lower', cmap='jet', extent=[0, len(T2D[0]), 0, len(T2D)])
plt.colorbar(label='U min')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r'Solution Exacte')

# Affichage de la différence
plt.subplot(1, 3, 3)
plt.imshow(diff, origin='lower', cmap='jet', extent=[0, len(diff[0]), 0, len(diff)])
plt.colorbar(label='Différence')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r'Différence Absolue')
# Out:
# Text(0.5, 1.0, 'Différence Absolue')

# %% [markdown]
# # Uzawa
#
# On considère le problème:
#
# $$
# \left\{
#     \begin{array}{ll}
#         \Delta u = f & \text{dans } \Omega \\
#         u = 0 & \text{sur } \partial \Omega
#     \end{array}
# \right.
# $$
#
# où $(u, f) \in V = \left\{ u \in H^1_0(\Omega), f \in L^2(\Omega) \; \big\lvert \; \Delta u = f \right\}.$
#
# On modélise $f:\mathbb{R}^2 \rightarrow \mathbb{R}$ par un polynôme de degré $n$ (donc avec $N_d = \frac{(n+1)(n+2)}{2}$ coefficients) :
#
# $$
# f(x,y) = \sum_{i+j  \leq n} \alpha_{i,j} x^i y^j = \sum_{k = 0}^{n} \sum_{i = 0}^{k} \alpha_{k,i} x^i y^{k-i} = \sum_{k = 0}^{n} \sum_{i = 0}^{k} \alpha_{s} x^i y^{k-i}
# $$
#
# où $s = \frac{k(k+1)}{2} + i$.
#
# Le système obtenu par différences finis est $AU = b$, on peut donc décomposer le second membre de la manière suivante b = M F avec :
#
# $$
# M = \begin{pmatrix}
# x_0^0 y_0^0 & x_0^1 y_0^0 & x_0^0 y_0^1 & x_0^2 y_0^0 & x_0^1 y_0^1 & x_0^0 y_0^2 & ... & x_0^0 y_0^n\\
# x_1^0 y_1^0 & x_1^1 y_1^0 & x_1^0 y_1^1 & x_1^2 y_1^0 & x_1^1 y_1^1 & x_1^0 y_1^2 & ... & x_1^0 y_1^n\\
# . & . & . & . & . & . &  ... & .\\
# . & . & . & . & . & . &  ... & .\\
# . & . & . & . & . & . &  ... & .\\
# x_{N_m}^0 y_{N_m}^0 & x_{N_m}^1 y_{N_m}^0 & x_{N_m}^0 y_{N_m}^1 & x_{N_m}^2 y_{N_m}^0 & x_{N_m}^1 y_{N_m}^1 & x_{N_m}^0 y_{N_m}^2 & ... & x_{N_m}^0 y_{N_m}^n
# \end{pmatrix}
# $$
#
# $$
# \text{ou plus simplement  }M = \begin{pmatrix}
# 1 & x_0 & y_0 & x_0^2 & x_0 y_0 & y_0^2 & ... & y_0^n\\
# 1 & x_1& y_1 & x_1^2 & x_1 y_1 & y_1^2 & ... & y_1^n\\
# . & . & . & . & . & . &  ... & .\\
# . & . & . & . & . & . &  ... & .\\
# . & . & . & . & . & . &  ... & .\\
# 1 & x_{N_m} & y_{N_m} & x_{N_m}^2 & x_{N_m} y_{N_m} & y_{N_m}^2 & ... & y_{N_m}^n
# \end{pmatrix}
# $$
#
#
#
# et $F = (\alpha_{s})_{0 \leq s < N_d}$, avec  $(x_k,y_k)_{0 \leq k \leq N_m}$ les point du maillages où $N_m = N_x N_y - 1$.
#
#
#
# On réécrit sous forme vectorielle la fonctionnelle $I(u) = \sum_{i \in E_m} (u(x_i, y_i) - T_i)^2$ où $E_m$ représente l'ensemble des indices $i \in [0, N_x N_y]$ des points $(x_i, y_i)$ où la solution exacte $T$ est mesurée:
#
# $$
#     I(u) = (U-T,U-T)_{\Gamma} = (U-T) \Gamma (U-T)
# $$
#
# où $U = (u(x_i, y_j))_{(i,j) \in [0, N_x] \times [0, N_y]}$,  $T = (T_k)_{k \in [0, N_x N_y]}$ et $\Gamma$ la matrice non inversible suivante:
#
# $$
# \Gamma_{ij} =
# \begin{cases}
# 1, & \text{si } i=j \text{ et } i \in E_m\\
# 0, & \text{sinon}
# \end{cases}
# $$
#
#
#
# On introduit maintenant les notations suivantes:
#
# $$
# V' = \{(U,F) \in \mathbb{R}^{N_xN_y} \times \mathbb{R}^{N_d} | A U = M F\} \hspace{0.5cm} \text{ et } \hspace{0.5cm} B = (A \hspace{0.2cm} -M)
# $$
#
#
# $$
# \Gamma^* \in \mathcal{M}_{N_x N_y + N_d}(\mathbb{R}) \text{, tel que } \hspace{0.5cm} \Gamma_{ij}^* =
# \begin{cases}
# \epsilon + 1, & \text{si } i=j \text{ et } i \in E_m\\
# \epsilon, & \text{sinon}
# \end{cases}
# $$
#
# Il faut maintenant minimiser le Lagrangien par rapport à $X$ avant de le mettre à jour $\lambda$ avec le Gradient Projeté, pour cela on cherche à annuler le gradient du Lagrangien par rapport à $X$:
#
# $$
# \nabla_X \mathcal{L}(X,\lambda) = \nabla_X  I^*(X) - B^T \lambda = \Gamma^* (X - T^*) - B^T \lambda = 0
# $$
#
# où $X \in V'$, $T \in \mathbb{R}^{N_xN_y} \times \mathbb{R}^{N_d}$ tel que $(T_k^*)_{0 \leq k \leq N_m} = T$ est la solution exacte vérifiant $A T = b$ et minimisant I(T) à retrouver et $(T_k^*)_{0 \leq k \leq N_m} = 0$.
#
#
# L'algorithme d'Uzawa est donné pur $\nu > 0$ par :
#
# $$
# \begin{cases}
# X^{n+1} &= (\Gamma^*)^{-1} B^T \lambda^n + T^*\\
# \lambda^{n+1} &= \lambda^n - \nu B X^n
# \end{cases}
# $$

# %%
def gradient_conjugue(A, b, u0, max_iter=1000, epsilon=1e-7):
    u = u0 * np.ones(len(b))
    rk = b - np.dot(A, u)
    p = rk
    k = 0

    while np.linalg.norm(rk) > epsilon and k < max_iter:
        Ap = np.dot(A, p)
        alpha = np.dot(rk, p) / np.dot(Ap, p)
        u += alpha * p
        rkp1 = rk - alpha * Ap
        beta = np.dot(rkp1, rkp1) / np.dot(rk, rk)
        p = rkp1 + beta * p
        rk = rkp1
        k += 1

    return u, k, np.linalg.norm(rk)

# %%
from tqdm.notebook import tqdm

# Définition des paramètres

# Second membre
n = 2 # dégré du polynôme interpolant f
Nd = int((n+1) * (n+2) / 2)
# Discrétisation
Nx = 100
Ny = 100
# Dimensions
H = 7
L = 7
# Maillage : taille et points
dx = L / (Nx+1)
dy = H / (Ny+1)
P = np.array([[[i * dx, j * dy] for i in range(1, Nx + 1)] for j in range(1, Ny + 1)]) 
P = P.reshape(Nx*Ny, 2)
# Nombre de points de mesures de la température exacte < Nx*Ny
N = 10000 

# Matice second membre polynomial
M = []
for k in range(n+1):
    for i in range(k+1):
        # [x^0y^0, x^0y^1, x^1y^0, x^0y^2, x^1y^1, x^2y^0, ...]
        M.append((P[:,0] ** i) * (P[:,1] ** (k - i)))
M = np.array(M)


# Définition du terme source
def TS(x,y):
    return 2 * (x**2 + y**2 - (L*x + H*y)) / (L*H)


# Résolution du problème (solution exacte)
Uex, A, bex, Tex = heat(Nx, Ny, 0, TS, H=H, L=L, epsilon=1e-7)

#Définition des Variables X, T, Lambda, B pour l'algo d'Uzawa
B = np.concatenate([A, -M]).T
Bc = np.dot(B,B.T)
X = np.zeros(Nx*Ny + Nd)
Lambda = np.zeros(Nx*Ny)
T = Tex.flatten()
alphaTrue = 2 * np.array([0, -L, -H, 1, 0, 1]) / (L*H)
Tf = np.concatenate([T, np.zeros(Nd)]) #

# Définition de Gamma et son inverse Gm1
epsilon = 1e-3
Gamma = np.ones(Nx*Ny+Nd) * epsilon
GammaAUX =  np.zeros(Nx*Ny+Nd) 
# Indices des points non nuls sur la diagonale
indices = np.concatenate([np.linspace(0, Nx*Ny - 1, N, dtype=int), np.linspace(Nx*Ny, Nx*Ny+Nd-1, Nd, dtype=int)])
# Placement des 1 sur la diagonale à ces indices
Gamma[indices] += 1
GammaAUX[indices] += 1
Gm1 = 1 / Gamma

nbiter = 1
nu = 1e-3
errmax = []
mse = []


# Création de l'instance de la barre de progression
pbar = tqdm(range(nbiter), desc="Processing")

for i in pbar:
    X =  Gm1 * np.dot(B.T,Lambda) + Gamma * Tf
    Lambda = Lambda - nu * np.dot(B,X)
    #Lb = np.dot(B, Gamma * (X-Tf))
    #Lambda, k, rkLD = gradient_conjugue(Bc, Lb, Lambda)
    u = X[:Nx*Ny]
    F = X[Nx*Ny:]
    b = np.dot(M.T,F)
    #u, k, rk = gradient_conjugue(A, b, u)
    #X[:Nx*Ny] = u
    rk = np.linalg.norm(np.dot(A,u) - b)
    errmax.append(np.abs(u - T).max() / np.abs(T).max())
    mse.append(np.mean((u - T) ** 2) / np.mean(T ** 2))
    #nu = errmax[-1]/10
    # Mise à jour de la barre de progression avec la valeur de l'erreur
    pbar.set_postfix(erreur_max_absolue=errmax[-1], mse = mse[-1], itérations_CG=k, erreur_CG=rk)
# Out:
# Nombre d'itérations du gradient conjugué:  178
# Résidu du gradient conjugué:  8.946719366839688e-08
# Processing:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
errmax = np.array(errmax)
mse = np.array(mse)

u2D = u.reshape(Nx, Ny)
T2D = T.reshape(Nx, Ny)

# Calcul de la différence
diff = np.abs(u2D - T2D)

plt.plot(np.arange(0, mse.shape[0], 1), errmax, label=r'$L_{\infty}$')
plt.plot(np.arange(0, mse.shape[0], 1), mse, label=r'MSE')
#plt.ylim(0, 1)
plt.grid()
plt.xlabel('itérations')
plt.ylabel(r'$\frac{||u_{num} - u_{exacte} ||}{||u_{exacte}||}$', fontsize=14, fontweight='bold')
plt.title("Erreurs relative en fonction du nombre d'itérations")
plt.legend(loc='best')
plt.show()

# Ajustement de la taille de la figure pour une meilleure visibilité des barres de couleur
plt.figure(figsize=(10, 6)) # Figure plus large

# Affichage de la solution numérique
plt.imshow(u2D, origin='lower', cmap='jet', extent=[0, len(u2D[0]), 0, len(u2D)])
cbar = plt.colorbar(label=r'$U(x,y)$')
plt.xlabel(r'$x$', fontsize=14)
plt.ylabel(r'$y$', fontsize=14)
plt.title(r'Solution Numérique', fontsize=18)
cbar.set_label(r'$U(x,y)$', fontsize=16)  # Modifier ici selon votre préférence
cbar.ax.tick_params(labelsize=14)  # Modifier la taille de police des graduations de la barre de couleur

plt.show()

# Ajustement de la taille de la figure pour une meilleure visibilité des barres de couleur
plt.figure(figsize=(10, 6)) # Figure plus large

# Affichage de la solution numérique
plt.imshow(T2D, origin='lower', cmap='jet', extent=[0, len(T2D[0]), 0, len(T2D)])
cbar = plt.colorbar(label=r'$U(x,y)$')
plt.xlabel(r'$x$', fontsize=14)
plt.ylabel(r'$y$', fontsize=14)
plt.title(r'Solution Exacte', fontsize=18)
cbar.set_label(r'$U(x,y)$', fontsize=16)  # Modifier ici selon votre préférence
cbar.ax.tick_params(labelsize=14)  # Modifier la taille de police des graduations de la barre de couleur

plt.show()

# Ajustement de la taille de la figure pour une meilleure visibilité des barres de couleur
plt.figure(figsize=(15, 5)) # Figure plus large

# Affichage de la solution numérique
plt.subplot(1, 3, 2)
plt.imshow(u2D, origin='lower', cmap='jet', extent=[0, len(u2D[0]), 0, len(u2D)])
plt.colorbar(label='T numérique')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r'Solution Numérique')

# Affichage de la solution du gradient projeté
plt.subplot(1, 3, 1)
plt.imshow(T2D, origin='lower', cmap='jet', extent=[0, len(T2D[0]), 0, len(T2D)])
plt.colorbar(label='U min')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r'Solution Exacte')

# Affichage de la différence
plt.subplot(1, 3, 3)
plt.imshow(diff, origin='lower', cmap='jet', extent=[0, len(diff[0]), 0, len(diff)])
plt.colorbar(label='Différence')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r'Différence Absolue')
# Out:
# Text(0.5, 1.0, 'Différence Absolue')

# %% [markdown]
# # Autre essai

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.sparse import diags
from scipy.sparse.linalg import spsolve
from sklearn.datasets import make_regression

# Paramètres du domaine
Lx, Ly = 1.0, 1.0
nx, ny = 50, 50
dx, dy = Lx / (nx + 1), Ly / (ny + 1)

# Construction de la matrice A
kx, ky = 1 / dx**2, 1 / dy**2
diagonal = 2 * (kx + ky) * np.ones(nx * ny)
off_diagonal_x = -kx * np.ones(nx * ny - 1)
off_diagonal_y = -ky * np.ones(nx * ny - nx)

A = diags([diagonal, off_diagonal_x, off_diagonal_x, off_diagonal_y, off_diagonal_y],
          [0, -1, 1, -nx, nx], format="csr")

# Fonction pour la solution exacte
def u_exact(x, y, L=Lx, H=Ly):
    return x * y * (L - x) * (H - y) / (L * H)

# Création de la solution exacte sur le maillage
X, Y = np.meshgrid(np.linspace(0, Lx, nx), np.linspace(0, Ly, ny))
U_exact = u_exact(X, Y).flatten()

# Conditions aux limites (pour simplifier, on les met à zéro)
b = np.zeros(nx * ny)

# Choix de Nm points de mesure uniformément répartis
Nm = nx * ny
points = make_regression(n_samples=Nm, n_features=2, noise=0.1, random_state=42)[0]
points = (points - points.min(axis=0)) / (points.max(axis=0) - points.min(axis=0))
points[:, 0] *= (Lx - 2 * dx)  # Éviter les bords
points[:, 1] *= (Ly - 2 * dy)  # Éviter les bords
points += [dx, dy]  # Décaler pour éviter les bords

# Ajout des mesures dans b
for x, y in points:
    i, j = int(x // dx), int(y // dy)
    k = i + nx * j
    if k < len(b):
        b[k] = U_exact[k]

# Paramètres pour Uzawa
lambda_ = np.zeros_like(b)
nu = 1e-3  # Pas de descente
epsilon = 1e-8  # Seuil de tolérance pour la convergence
max_iter = 1000000  # Nombre maximum d'itérations

# Algorithme d'Uzawa
for _ in range(max_iter):
    # Résolution de AU = b + lambda_
    U = spsolve(A, b + lambda_)

    # Mise à jour de lambda_
    lambda_ = lambda_ - nu * (A.dot(U) - b)

    # Vérification de la convergence
    if np.linalg.norm(A.dot(U) - b) < epsilon:
        break

# Différence absolue entre la solution Uzawa et la solution exacte
difference = np.abs(U_exact - U)

# Affichage des résultats
plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plt.imshow(U.reshape(nx, ny), extent=(0, Lx, 0, Ly))
plt.title("Solution par Uzawa")
plt.colorbar()

plt.subplot(1, 3, 2)
plt.imshow(U_exact.reshape(nx, ny), extent=(0, Lx, 0, Ly))
plt.title("Solution exacte")
plt.colorbar()

plt.subplot(1, 3, 3)
plt.imshow(difference.reshape(nx, ny), extent=(0, Lx, 0, Ly))
plt.title("Différence absolue")
plt.colorbar()

plt.show()

# %% [markdown]
# # Méthode de l'équation des sensibilités et de l'équation adjointe

# %%
import numpy  as np
import time
import random as rd
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.sparse import diags
import scipy.linalg as sp
from functools import partial
import sys

# Définition des paramètres

Nx = 20
Ny = 20
H = 7
L = 7
dx = L / (Nx+1)
dy = H / (Ny+1)

def u_exact(x,y):
    return x*y*(L-x)*(H-y) / (L * H)

# En 1 : appeler heat pour calculer u
def heat(nx, ny, f, c=0, low_bool=0,  decomp=False, L=1, H=1):
    """ Fonction simulant l'équation de la chaleur stationnaire 2D sur un maillage cartésien uniforme par différences finies
    avec des conditions aux limites de type Dirichlet homogène. Arguments :
        - nx : nombre de mailles selon x
        - ny : nombre de mailles selon y
        - u0 : solution initiale (scalaire)
        - f : terme source (fonction prenant 2 scalaires (x, y) en entrée pour retourner un scalaire f(x, y))
        - L : longueur du domaine (= 1 par défaut)
        - H : hauteur du domaine (= 1 par défaut)
        - max_iter : nombre maximal d'itérations pour le gradient conjugué (= 10000 par défaut)
        - epsilon : seuil d'erreur minimal pour le gradient conjugué (= 1e-7 par défaut) """

       # Construction du maillage : liste P des points P(i,j) = (x(i), y(j)) 
    # du maillage indexés par k = i - 1 + nx * (j - 1)
    N = nx * ny
    dx = L / (nx+1)
    dy = H / (ny+1)

    # Construction du système linéaire Au = b
    
    N = nx * ny
    b = np.zeros(nx*ny) # Second membre b
    for I in range(nx * ny):
        i = I % nx + 1
        j = I // nx + 1
        b[i-1 + (j-1)*nx] = f(i*dx, j*dy)
    # Résolution du système linéaire
    if decomp:
        alpha = - 2 * (1 / dx**2 + 1 / dy**2) * np.ones(N) # Diagonale de A
        beta = np.ones(N - 1) / dx ** 2 # Diagonales décalées de 1 indice
        beta[nx - 1::nx] = 0 # Brisures de la diagonale
        gamma = np.ones(N - nx) / dy ** 2 # Diagonale décalée de nx indices
        k = [gamma, beta, alpha, beta, gamma]
        offset = [-nx, -1, 0, 1, nx]
        A = diags(k, offset).toarray() # Matrice A
        c, low_bool = sp.cho_factor(-A, lower=True)
    u = -sp.cho_solve((c, low_bool), b)
    if decomp:
        return u, (c, low_bool)
    else:
        return u


# En 2 : appeler f pour calculer le second membre
def f(alpha, x, y):
   f_alpha = 0.0
   degre = int(len(alpha)/2)-1 # len(alpha) obligatoirement pair
   for j in range(degre+1):
      f_alpha += alpha[j] * x**j + alpha[degre+1+j] * y**j
   return f_alpha

# En 3 : calculer le gradient de la fonction coût
def gradIU(u, ue):
   gradIU_vect = np.zeros(len(u))
   for I in range(len(u)):
      if (ue[I] != -1):
         gradIU_vect[I] = 2 * (u[I] - ue[I])
   return gradIU_vect

# En 4 : calculer le gradient de f par rapport à alpha
def gradFalpha(degre):
   dalpha = np.zeros(2 * degre + 2)
   grad = np.zeros((Nx*Ny, len(dalpha)))
   for I in range(Nx * Ny):
      i = I % Nx + 1
      j = I // Nx + 1
      for k in range(len(dalpha)):
         dalpha[k] = 1
         grad[I][k] = f(dalpha, i * dx, j * dy)
         dalpha[k] = 0
   return grad

def Method(tau, degre, meth, kmax=50000):
   X, Y = np.meshgrid(np.linspace(0+dx, L-dx, Nx), np.linspace(0+dy, H-dy, Ny))
   U_exact = u_exact(X, Y)
   print(U_exact.max())
   k = 0
   gradNorm = 1
   epsilon = 1e-3
   nu = 1e-7
   # solution exacte
   alpha = np.array([0, -2/H, 2/(H*L), 0, -2/L, 2/(H*L)])
   print(alpha)
   alpha = np.zeros(2*degre+2)/2
   f_partial = partial(f, alpha)
   T, (c, low_bool) = heat(Nx, Ny, f_partial, decomp=True, L=L, H=H)
   jacobienne_f = gradFalpha(degre)
   gradUalpha = np.zeros((len(alpha),Nx*Ny))
   gradIalpha = np.zeros(len(alpha))
   gradIalpha1 = np.zeros(len(alpha))
   while(gradNorm > epsilon and k <= kmax):
      # calcul du gradient de I par rapport à T
      gradIU_vect = gradIU(T, tau)
      if meth == "adjoint":
         # calcul de lambda 
         lambdaa = -sp.cho_solve((c, low_bool), gradIU_vect)
         #calcul du gradient de I par rapport à alpha
         gradIalpha = lambdaa.T.dot(jacobienne_f)
      elif meth == "sensibilite":
         for m in range(len(alpha)):
            # calcul de gradU 
            gradUalpha[m] = -sp.cho_solve((c, low_bool), jacobienne_f[:,m])
            #calcul du gradient de I par rapport à alpha
            gradIalpha[m] = gradIU_vect.dot(gradUalpha[m]) 
      elif meth == "compare":
         # calcul de lambda 
         lambdaa = -sp.cho_solve((c, low_bool), gradIU_vect)
         #calcul du gradient de I par rapport à alpha
         gradIalpha = lambdaa.T.dot(jacobienne_f)
         for m in range(len(alpha)):
            # calcul de gradU 
            gradUalpha[m] = -sp.cho_solve((c, low_bool), jacobienne_f[:,m])
            #calcul du gradient de I par rapport à alpha
            gradIalpha1[m] = gradIU_vect.dot(gradUalpha[m])
         if (np.linalg.norm(gradIalpha1-gradIalpha, ord=2) > 1e-10):
            sys.exit('Les gradients ne sont pas égaux')
      gradNorm = np.linalg.norm(gradIalpha, ord=2)
      if (k % 4000 == 0):
            print("gradNorm =", k, gradNorm)
      alpha = alpha - nu * gradIalpha
      
      f_partial = partial(f, alpha)
      T = heat(Nx, Ny, f_partial, c, low_bool, L=L, H=H)
      k = k+1
   if (meth == "compare"):
      print ('Les méthodes donnent le même gradient à 10^-10 près')
   print(alpha)
   return T, alpha

# Définir les températures aux points de mesure
tau_l = -np.ones(Nx*Ny)
for I in range(Nx*Ny):
    i = I % Nx + 1
    j = I // Nx + 1
    if (I % 2 == 0):
        tau_l[I] = u_exact(i*dx, j*dy)

#T, alpha = Method(tau_l, 2, meth="adjoint")
#T, alpha = Method(tau_l, 2, meth="sensibilite")
T, alpha = Method(tau_l, 2, meth="compare")

# Calcul de la solution exacte
X, Y = np.meshgrid(np.linspace(0+dx, L-dx, Nx), np.linspace(0+dy, H-dy, Ny))
U_exact = u_exact(X, Y)
T = T.reshape(Ny, Nx)

diff_adjointes = np.abs(T - U_exact)

# Ajustement de la taille de la figure pour une meilleure visibilité des barres de couleur
plt.figure(figsize=(15, 5))  # Figure plus large

# Affichage de la solution numérique
plt.subplot(1, 3, 2)
plt.imshow(U_exact, origin='lower', cmap='jet', extent=[0, L, 0, H])
plt.colorbar(label='T numérique')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r'Solution exacte')

# Affichage de la solution de la méthode de sensibilité
plt.subplot(1, 3, 1)
plt.imshow(T, origin='lower', cmap='jet', extent=[0, L, 0, H])
plt.colorbar(label='T exacte')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r'Solution numérique')

# Affichage de la différence
plt.subplot(1, 3, 3)
plt.imshow(diff_adjointes, origin='lower', cmap='jet', extent=[0, L, 0, H])
plt.colorbar(label='Différence')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r'Différence Absolue')

plt.tight_layout()
plt.show()
# Out:
# 3.0486268581506675
# [ 0.         -0.28571429  0.04081633  0.         -0.28571429  0.04081633]
# gradNorm = 0 30848.085875856843
# gradNorm = 4000 157.6368381334974
# gradNorm = 8000 124.14972745567373
# gradNorm = 12000 97.77711940693287
# gradNorm = 16000 77.00770637076778
# gradNorm = 20000 60.65127622749583
# gradNorm = 24000 47.77050602147947
# gradNorm = 28000 37.62724759071186
# gradNorm = 32000 29.64022695976603
# gradNorm = 36000 23.351733329472253
# gradNorm = 40000 18.401388567785418
# gradNorm = 44000 14.505493690975047
# gradNorm = 48000 11.440768083420343
# Les méthodes donnent le même gradient à 10^-10 près
# [-0.12467256 -0.18730708  0.02582574 -0.12467256 -0.18744633  0.02585697]

# %% [markdown]
# # Gradient projeté

# %%
from tqdm.notebook import tqdm
from tqdm.auto import trange
import matplotlib.pyplot as plt
import numpy  as np

# Définition des paramètres
n = 2  # degré du polynôme interpolant f
Nd = int((n + 1) * (n + 2) / 2)

# Discrétisation
Nx = 20
Ny = 20
N = 5000

# Dimensions
H = 7
L = 7

# Maillage : taille et points
dx = L / (Nx + 1)
dy = H / (Ny + 1)
P = np.array([[[i * dx, j * dy] for i in range(1, Nx + 1)] for j in range(1, Ny + 1)])
P = P.reshape(Nx * Ny, 2)

# Matrice second membre polynomial
M = []
for k in range(n + 1):
    for i in range(k + 1):
        M.append((P[:, 0] ** i) * (P[:, 1] ** (k - i)))
M = np.array(M)
MT = M.T

# Définition du terme source
def TS(x, y):
    return 2 * (x**2 + y**2 - (L * x + H * y)) / (L * H)


def heat(nx, ny, u0, f, L=1, H=1, max_iter=10000, epsilon=1e-7):
    """ Fonction simulant l'équation de la chaleur stationnaire 2D sur un maillage cartésien uniforme par différences finies
    avec des conditions aux limites de type Dirichlet homogène. Arguments :
        - nx : nombre de mailles selon x
        - ny : nombre de mailles selon y
        - u0 : solution initiale (scalaire)
        - f : terme source (fonction prenant 2 scalaires (x, y) en entrée pour retourner un scalaire f(x, y))
        - L : longueur du domaine (= 1 par défaut)
        - H : hauteur du domaine (= 1 par défaut)
        - max_iter : nombre maximal d'itérations pour le gradient conjugué (= 10000 par défaut)
        - epsilon : seuil d'erreur minimal pour le gradient conjugué (= 1e-7 par défaut) """

       # Construction du maillage : liste P des points P(i,j) = (x(i), y(j)) 
    # du maillage indexés par k = i - 1 + nx * (j - 1)
    N = nx * ny
    dx = L / (nx+1)
    dy = H / (ny+1)
    P = np.array([[[i * dx, j * dy] for i in range(1, nx + 1)] for j in range(1, ny + 1)]) 
    P = P.reshape(N, 2)

    # Construction du système linéaire Au = b
    
    N = nx * ny
    alpha = 2 * (1 / dx**2 + 1 / dy**2) * np.ones(N) # Diagonale de A
    beta = - np.ones(N - 1) / dx ** 2 # Diagonales décalées de 1 indice
    beta[nx - 1::nx] = 0 # Brisures de la diagonale
    gamma = - np.ones(N - nx) / dy ** 2 # Diagonale décalée de nx indices
    k = [gamma, beta, alpha, beta, gamma]
    offset = [-nx, -1, 0, 1, nx]
    A = diags(k, offset).toarray() # Matrice A
    b = np.array([f(P[k, 0], P[k, 1]) for k in range(N)]) # Second membre b

    # Résolution du système linéaire
    
    u = u0 * np.ones(N) 
    rk = b - np.dot(A,u)
    p = rk
    k = 0
    kmax = max_iter

    while np.linalg.norm(rk) > epsilon and k < kmax:
        z = np.dot(A, p)
        alpha = np.dot(rk,p) / np.dot(z, p)
        u = u - alpha * p
        rkp1 = rk - alpha * z
        gamma =  np.dot(rkp1,rkp1) / np.dot(rk,rk)
        p = rkp1 + gamma * p
        rk = rkp1
        k += 1
        
    print("Nombre d'itérations du gradient conjugué: ", k)
    print("Résidu du gradient conjugué: ", np.linalg.norm(rk))

    u2D = u.reshape(Nx, Ny)
    u = np.zeros((Nx+2, Ny+2))
    u[1:-1, 1:-1] = u2D

    
    return u, A, b, u2D

# Résolution du problème (solution exacte)
Uex, A, bex, Tex = heat(Nx, Ny, 0, TS, H=H, L=L, epsilon=1e-7)

# Définition des Variables X, T, Lambda, B pour l'algo d'Uzawa
T = Tex.flatten()
Tf = np.concatenate([T, np.zeros(Nd)])
B = np.hstack([A, -MT])
BBTinv = np.linalg.inv(B @ B.T)
Ainv = np.linalg.inv(A)

# Définition de Gamma et son inverse Gm1
epsilon = 1e-7
Gamma = np.ones(Nx * Ny)

indices = np.linspace(0, Nx * Ny - 1, N, dtype=int)
Gamma[indices] += 1
Gamma = np.diag(Gamma)
Gamma = np.hstack([Gamma, np.zeros((Nx * Ny, Nd))])
Gamma += epsilon

errmax = []
mse = []

def gradient_projete(Xvec):
    global Gamma, Ainv, M, T, B, BBTinv
    U = Xvec
    gradI_u = Gamma @ (U - Tf)
    grad_alpha = gradI_u @ Ainv @ MT
    gradI_x = np.hstack([gradI_u, grad_alpha])
    ca = (B @ gradI_x)
    Lambda = BBTinv @ ca
    G = gradI_x - B.T @ Lambda
    return G

# Initialisation des paramètres
seuil = 1.e-3
pas_descente = 1.e-3
nb_iterations_max = 1_000
u0 = np.zeros(Nx * Ny + Nd)
u = u0

# Boucle de descente de gradient avec projection
for nb_iter in range(1, nb_iterations_max):
    # Calcul du gradient projeté
    G = gradient_projete(u)
    normG = np.linalg.norm(G)
    if (normG < seuil):
        break
    # Descente à pas constant
    u -= pas_descente * G / normG
    errmax.append(np.abs(u - Tf).max() / np.abs(Tf).max())
    mse.append(np.mean((u - Tf) ** 2) / np.mean(Tf ** 2))
    pas_descente = errmax[-1] / 5

# Tronquer la solution pour enlever les composantes ajoutées
u = u[:Nx * Ny]

# Erreurs
errmax = np.array(errmax)
mse = np.array(mse)

u2D = u.reshape(Nx, Ny)
T2D = T.reshape(Nx, Ny)

# Calcul de la différence
diff = np.abs(u2D - T2D)

# Affichage des erreurs
plt.plot(np.arange(0, mse.shape[0], 1), errmax, label=r'$L_{\infty}$')
plt.plot(np.arange(0, mse.shape[0], 1), mse, label=r'MSE')
plt.ylim(0, 1.25)
plt.grid()
plt.xlabel('Itérations')
plt.ylabel(r'$\frac{||u_{num} - u_{exacte} ||}{||u_{exacte}||}$', fontsize=14, fontweight='bold')
plt.title("Erreurs relatives en fonction du nombre d'itérations")
plt.legend(loc='best')
plt.show()

# Ajustement de la taille de la figure pour une meilleure visibilité des barres de couleur
plt.figure(figsize=(15, 5))

# Affichage de la solution numérique
plt.subplot(1, 3, 2)
plt.imshow(u2D, origin='lower', cmap='jet', extent=[0, len(u2D[0]), 0, len(u2D)])
plt.colorbar(label='T numérique')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r'Solution Numérique')

# Affichage de la solution du gradient projeté
plt.subplot(1, 3, 1)
plt.imshow(T2D, origin='lower', cmap='jet', extent=[0, len(T2D[0]), 0, len(T2D)])
plt.colorbar(label='U min')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r'Solution Exacte')

# Affichage de la différence
plt.subplot(1, 3, 3)
plt.imshow(diff, origin='lower', cmap='jet', extent=[0, len(diff[0]), 0, len(diff)])
plt.colorbar(label='Différence')
plt.xlabel('x')
plt.ylabel('y')
plt.title(r'Différence Absolue')
plt.show()
# Out:
# Nombre d'itérations du gradient conjugué:  33
# Résidu du gradient conjugué:  8.305637458204227e-08
